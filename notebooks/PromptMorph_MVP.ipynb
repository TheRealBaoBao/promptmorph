# %% [markdown]
# # PromptMorph MVP
# This notebook is a thin Colab launcher. Production logic lives in the tested Python package. It records one physical prompt, moves the cup during deployment, replans, and writes native sensorimotor episode data.

# %%
# %pip install -q -e '.[dev,sim,ml]'
# !pytest -q
# !promptmorph-mujoco-demo --seed 7 --output-dir artifacts
