# %% [markdown]
# # PromptMorph MVP
# This notebook is a thin Colab launcher. Production logic lives in the tested Python package.

# %%
# %pip install -q -e '.[dev,sim,ml]'
# !pytest -q
# !python -m promptmorph.cli
